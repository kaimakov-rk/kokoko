# %% [markdown]
# <a href="https://colab.research.google.com/github/kaimakov-rk/kokoko/blob/master/Copy_of_%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 3

# %% [markdown]
# ##Обработка пропущенных значений

# %% [markdown]
# Обработайте пропущенные значения:
#
#
# * Удалите пропущенные значения
# * Заполните при помощи медианы, среднего для числовых значений
# * Заполните при помощи моды для категориальных значений
# * Интерполируйте
# Выведите статистку после каждого метода и объясните

# %%
# !pip install scikit-learn

# %%
import pandas as pd

df = pd.read_csv('/content/predictive_maintenance.csv')

# %%
import pandas as pd
import numpy as np

def create_holes(dataframe, column_name, hole_percentage = 10):
    """
    Создает "дыры" в указанной колонке заданного DataFrame.

    Parameters:
        dataframe (pd.DataFrame): Исходный DataFrame.
        column_name (str): Имя колонки, в которой нужно создать "дыры".
        hole_percentage (float): Процент дырявости, который указывает, какую часть данных следует заменить на NaN.

    Returns:
        pd.DataFrame: DataFrame с "дырами" в указанной колонке.
    """
    if hole_percentage < 0 or hole_percentage > 100:
        raise ValueError("Процент дырявости должен быть в диапазоне от 0 до 100.")

    dataframe_with_holes = dataframe.copy()
    num_holes = int(len(dataframe) * (hole_percentage / 100))
    hole_indices = np.random.choice(len(dataframe), num_holes, replace=False)
    dataframe_with_holes.loc[hole_indices, column_name] = np.nan

    return dataframe_with_holes


column_name = "Torque [Nm]"
df = create_holes(df, column_name)
df.isna().sum()
# Out:
# UDI                           0
# Product ID                    0
# Type                          0
# Air temperature [K]           0
# Process temperature [K]       0
# Rotational speed [rpm]        0
# Torque [Nm]                1000
# Tool wear [min]               0
# Target                        0
# Failure Type                  0
# dtype: int64

# %%
#Удаление

df_filtered = df.dropna()
df_filtered.isna().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
#Заполнение при помощи медианы
median = df_filtered[column_name].median()
print (f"Median: {median}")
df.fillna(median)
# Out:
# Median: 40.0
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
# ...

# %%
#Заполнение при помощи среднего
mean = df_filtered[column_name].mean()
print(f"Mean: {mean}")
df.fillna(mean)
# Out:
# Mean: 39.94096666666667
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
# ...

# %%
#Заполнение при помощи моды
mode = df_filtered[column_name].mode()
print(f"Mode: {mode}")
df.fillna(mode)
# Out:
# Mode: 0    36.6
# 1    40.6
# Name: Torque [Nm], dtype: float64
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
# ...

# %%
#Заполнение при помощи интерполяции
print(f"Before: {df.isna()[column_name].sum()}")
new_df = df.interpolate(method='index')
print(f"After: {new_df.isna()[column_name].sum()}")
new_df
# Out:
# Before: 1000
# After: 1
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
# ...

# %% [markdown]
# **Объясните**

# %% [markdown]
# ##Поиск выбросов и аномалий

# %% [markdown]
# **Те, кто выполняет задания со * делают поиск выбросов с помощью написанного ранее класса**
#
# Найти выбросы по числовой переменной (использовать метод основанный на среднем и на межквартильном размахе). Объясните результат
#
# Вывести статистику с выбросами и без. Сравните и объясните результат

# %%
# Класс

from typing import TypeAlias, Text
from copy import deepcopy
from math import erfc
from sklearn.cluster import DBSCAN


DataFrame: TypeAlias = pd.core.frame.DataFrame


class OutlierCleanser:
  def __init__(self, df: DataFrame):
    self.__df = df

  @property
  def df(self):
    return self.__df

  def clean_by_std_and_mean(self, column_name: Text) -> DataFrame:
    result: DataFrame = deepcopy(self.__df)
    mean: float = result[column_name].mean()
    std: float = result[column_name].std()
    return result[result.apply(lambda x: abs(x[column_name] - mean) < 2 * std,
                               axis=1, result_type='reduce')].dropna()

  def clean_by_chauvenet(self, column_name: Text) -> DataFrame:
    result: DataFrame = deepcopy(self.__df)
    iteration: int = 0
    n: int = len(result[column_name])
    while n > 1:
      mean: float = result[column_name].mean()
      std: float = result[column_name].std()
      to_drop: list = list()
      for i, x in enumerate(result[column_name]):
        if std > 0.0 and erfc((abs(x - mean) / 2**0.5) / std) < 1.0/(2*n):
          to_drop += [i, ]
      result = result.drop(to_drop)
      new_n: int = len(result[column_name])
      if new_n < n:
        n = new_n
        iteration += 1
      else:
        return result

  def clean_by_quartiles(self, column_name: Text) -> DataFrame:
    result: DataFrame = deepcopy(self.__df)
    q1: float = result[column_name].quantile(0.25)
    q3: float = result[column_name].quantile(0.75)
    iqr: float = q3 - q1
    result = result[q1 - 1.5 * iqr <= result[column_name]]
    result = result[result[column_name] <= q3 + 1.5 * iqr]
    return result

  def clean_by_2_variables_1_dataframe(self,
                                       column_name_1: Text,
                                       column_name_2: Text) -> DataFrame:
    result: DataFrame = deepcopy(self.__df)
    pairs = list()
    for index, row in result.iterrows():
      pairs.append([row[column_name_1], row[column_name_2]])
    clustering = DBSCAN(eps=2, min_samples=2).fit(pairs)
    outliers = list(filter(lambda ivp: ivp[1] == -1,
                           enumerate(clustering.labels_)))
    return result.drop(map(lambda ivp: ivp[0], outliers))

# %%
#Методом среднего
df[column_name] = df[column_name].astype('float')
oc = OutlierCleanser(df)
oc.clean_by_std_and_mean(column_name).describe()
# Out:
#                 UDI  Air temperature [K]  Process temperature [K]  \
# count   8577.000000          8577.000000              8577.000000
# mean    5000.410866           299.999487               310.002472
# std     2895.567730             2.007898                 1.485796
# min        2.000000           295.300000               305.700000
# 25%     2498.000000           298.300000               308.800000
# 50%     4995.000000           300.100000               310.100000
# 75%     7503.000000           301.500000               311.100000
# max    10000.000000           304.500000               313.800000
#
#        Rotational speed [rpm]  Torque [Nm]  Tool wear [min]       Target
# count             8577.000000  8577.000000      8577.000000  8577.000000
# mean              1528.836306    39.908103       107.779293     0.021919
# std                140.315357     8.781271        63.467494     0.146428
# min               1212.000000    20.000000         0.000000     0.000000
# ...

# %%
#При помощи межквартильного размаха
oc = OutlierCleanser(df)
new_df = oc.clean_by_quartiles(column_name)
new_df.describe()
# Out:
#                 UDI  Air temperature [K]  Process temperature [K]  \
# count   8946.000000          8946.000000              8946.000000
# mean    5001.841717           300.004270               310.003163
# std     2891.105307             2.006044                 1.485294
# min        2.000000           295.300000               305.700000
# 25%     2502.250000           298.300000               308.800000
# 50%     5000.500000           300.100000               310.100000
# 75%     7495.750000           301.500000               311.100000
# max    10000.000000           304.500000               313.800000
#
#        Rotational speed [rpm]  Torque [Nm]  Tool wear [min]       Target
# count             8946.000000  8946.000000      8946.000000  8946.000000
# mean              1537.832886    39.895529       107.820367     0.028840
# std                170.061621     9.746676        63.494759     0.167365
# min               1168.000000    12.700000         0.000000     0.000000
# ...

# %%
#Статистика и объяснение

df.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# mean    5000.50000           300.004930               310.005560
# std     2886.89568             2.000259                 1.483734
# min        1.00000           295.300000               305.700000
# 25%     2500.75000           298.300000               308.800000
# 50%     5000.50000           300.100000               310.100000
# 75%     7500.25000           301.500000               311.100000
# max    10000.00000           304.500000               313.800000
#
#        Rotational speed [rpm]  Torque [Nm]  Tool wear [min]        Target
# count            10000.000000  9000.000000     10000.000000  10000.000000
# mean              1538.776100    39.940967       107.951000      0.033900
# std                179.284096     9.993029        63.654147      0.180981
# min               1168.000000     3.800000         0.000000      0.000000
# ...

# %% [markdown]
# **Объяснения**
#
# Из вышеприведённых статистических данных видно, что какие-то строки удалились (это видно из строки **count**), при этом в как среднее значение, так и стандартное отклонение увеличились, что говорит о том, что удалённые выбросы имели в основном небольшие значения.

# %% [markdown]
# ##Дубликаты

# %% [markdown]
# Проверьте датафрейм на дубликаты и удалите их, если дублей нет - создайте.

# %%
#Проверка на дубли

True in list(new_df.duplicated())
# Out:
# False

# %% [markdown]
# Дублей нет, нужно создать.

# %%
# Создание дублей

new_df = pd.concat([new_df, new_df.iloc[3:10]])
True in list(new_df.duplicated())
# Out:
# True

# %%
#Удаление дублей

new_df = new_df.drop_duplicates()

if not True in list(new_df.duplicated()):
  print('Дубли удалены')
else:
  print('Дубли не удалены')

new_df
# Out:
# Дубли удалены
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# 5         6     M14865    M                298.1                    308.6
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
# ...

# %% [markdown]
# ## Преобразование признаков

# %% [markdown]
# Масштабируйте числовые признаки через MinMaxScaler, StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Creating instances
min_max_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

new_df[['Rotational speed [rpm]']] = min_max_scaler.fit_transform(new_df[['Rotational speed [rpm]']])
new_df[['Tool wear [min']] = standard_scaler.fit_transform(new_df[['Tool wear [min]']])

new_df[['Rotational speed [rpm]', 'Tool wear [min]']].describe()
# Out:
#        Rotational speed [rpm]  Tool wear [min]
# count             8946.000000     8.946000e+03
# mean                 0.250734    -8.617694e-17
# std                  0.115296     1.000056e+00
# min                  0.000000    -1.698194e+00
# 25%                  0.173559    -8.634324e-01
# 50%                  0.227797     2.829263e-03
# 75%                  0.301695     8.533407e-01
# max                  1.000000     2.286610e+00

# %% [markdown]
# Масштабируйте категориальные признаки через OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# Create an instance of OneHotEncoder
encoder = OneHotEncoder()

new_df[['Type']] = encoder.fit(new_df[['Type']]).transform(new_df[['Type']])
new_df[['Product ID']] = encoder.fit_transform(new_df[['Product ID']])

new_df[['Type', 'Product ID']]
# Out:
#                Type        Product ID
# 1       (0, 1)\t1.0     (0, 892)\t1.0
# 2       (0, 1)\t1.0     (0, 893)\t1.0
# 3       (0, 1)\t1.0     (0, 894)\t1.0
# 4       (0, 1)\t1.0     (0, 895)\t1.0
# 5       (0, 2)\t1.0    (0, 6256)\t1.0
# ...             ...               ...
# 9995    (0, 2)\t1.0    (0, 8943)\t1.0
# 9996    (0, 0)\t1.0     (0, 890)\t1.0
# 9997    (0, 2)\t1.0    (0, 8944)\t1.0
# 9998    (0, 0)\t1.0     (0, 891)\t1.0
# 9999    (0, 2)\t1.0    (0, 8945)\t1.0
#
# [8946 rows x 2 columns]

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать расчет корреляции Спирмана

# %%
#Функция по расчету тут

import pandas as pd
import numpy as np
from collections import Counter


def corr_spearman(col1, col2):
  def my_mean(col):
    s = 0
    for elem in col:
      s += elem
    return s / len(col)

  def my_sqrt(n):
    return n ** (1/2)

  def my_std(col, mean=None):
    s = 0
    m = my_mean(col) if mean == None else mean
    for elem in col:
      s += (elem - m) ** 2
    return my_sqrt(s)

  def my_len(col):
    cnt = 0
    for elem in col:
      cnt += 1
    return cnt

  def my_rank(col):
    mapping = dict()
    data = list(enumerate(reversed(sorted(col))))
    for i, x in data:
      r = sum(map(lambda z: 1 if z[1] < x else 0, data))
      n = sum(map(lambda z: 1 if z[1] == x else 0, data))
      mapping[x] = r + (n - 1) / 2
    return [mapping[x] for x in col]

  rank1 = my_rank(col1)
  rank2 = my_rank(col2)

  mean1 = my_mean(col1)
  mean2 = my_mean(col2)

  s = 0
  i = 0
  l = my_len(col1)

  while i < l:
    s += (rank1[i] - mean1) * (rank2[i] - mean2)
    i += 1

  cov = s / (l - 1)

  std1 = my_std(rank1)
  std2 = my_std(rank2)

  n = my_len(col1)
  s1 = sum(rank1)
  s2 = sum(rank2)
  s12 = sum(map(lambda x: x[0] * x[1], zip(rank1, rank2)))
  ss1 = sum(map(lambda x: x[0] * x[1], zip(rank1, rank1)))
  ss2 = sum(map(lambda x: x[0] * x[1], zip(rank2, rank2)))

  return (n * s12 - s1 * s2) / my_sqrt((n * ss1 - s1 ** 2) * (n * ss2 - s2 ** 2))

# %%
#Пример использования тут и объяснение принципа работы

data1 = {
    'Рост': [170, 155, 180, 162, 175],
    'Вес':  [65, 50, 75, 55, 70]
}

data2 = {
    'Рост': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'Вес':  [100, 90, 80, 70, 60, 50, 40, 30, 20]
}

data3 = {
    'Рост': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'Вес':  [100, 0, 80, -10, 60, -4, 4, 3, 200]
}

data = data3

my_pdf = pd.DataFrame(data)
corr_spearman(my_pdf["Рост"], my_pdf["Вес"])
# Out:
# 0.06666666666666667

# %% [markdown]
# ###Пример реализации

# %%
import pandas as pd
import numpy as np


def corr_pearson(column_1, column_2):
  cov = np.cov(column_1, column_2)
  return cov/(column_1.std() * column_2.std())

# %%
data = {
    'Рост': [170, 155, 180, 162, 175],
    'Вес': [65, 50, 75, 55, 70]
}
pdf = pd.DataFrame(data)
pdf
# Out:
#    Рост  Вес
# 0   170   65
# 1   155   50
# 2   180   75
# 3   162   55
# 4   175   70

# %%
corr_pearson(pdf["Рост"], pdf["Вес"])
# Out:
# array([[0.96593129, 0.99674864],
#        [0.99674864, 1.03527033]])
